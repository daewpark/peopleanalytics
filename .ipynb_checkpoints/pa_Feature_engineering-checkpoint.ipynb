# %%
import pandas as pd
df = pd.read_excel("resources/mean median mode.xlsx")
df.head()
# Out:
#    age              department  employee_number  gender  job_level  \
# 0   41                   Sales                1  Female          2
# 1   49  Research & Development                2    Male          2
# 2   37  Research & Development                4    Male          1
# 3   33  Research & Development                5  Female          1
# 4   27  Research & Development                7    Male          1
#
#   marital_status over_time  performance_rating  totalW_working_years  \
# 0         Single       Yes                   3                     8
# 1        Married        No                   4                    10
# 2         Single       Yes                   3                     7
# 3        Married       Yes                   3                     8
# 4        Married        No                   3                     6
#
#    training_times_last_year  years_since_last_promotion  \
# 0                         0                           0
# 1                         3                           1
# 2                         3                           0
# 3                         3                           3
# 4                         3                           2
#
#    years_with_curr_manager  monthly_income  salary_2017  salary_2018  \
# 0                        5            5993        71916     79826.76
# 1                        7            5130        61560     75718.80
# 2                        0            2090        25080     28842.00
# 3                        0            2909        34908     38747.88
# 4                        2            3468        41616     46609.92
#
#    year_of_joining  last_role_change  percent_hike
# 0             2012              2014            11
# 1             2008              2011            23
# 2             2018              2018            15
# 3             2010              2011            11
# 4             2016              2016            12

# %%
df["Tenure"] =2020-df["year_of_joining"]
df["Tenure"]
# Out:
# 0        8
# 1       12
# 2        2
# 3       10
# 4        4
#         ..
# 1465     7
# 1466     9
# 1467     8
# 1468    11
# 1469     6
# Name: Tenure, Length: 1470, dtype: int64

# %%
df["Tenure"].describe()
# Out:
# count    1470.000000
# mean        9.008163
# std         6.126525
# min         2.000000
# 25%         5.000000
# 50%         7.000000
# 75%        11.000000
# max        42.000000
# Name: Tenure, dtype: float64

# %% [markdown]
# <h3> Dummy Variable </h3>
# 컴퓨터가 읽을 수 없는 변수를 바이너리 변수로 바꾸는 것. (여자 => 1, 남자 => 0) <p>
# 원칙 : 한 개 변수에 n개의 카테고리가 있으면 n-1 변수로 전환.

# %%
df["department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: department, dtype: int64

# %%
import numpy as np
df["hr_dummy"] = np.where((df["department"] == "Human Resources"),1,0)
df["sales_dummy"] = np.where((df["department"] == "Sales"),1,0)
df.head()
# Out:
#    age              department  employee_number  gender  job_level  \
# 0   41                   Sales                1  Female          2
# 1   49  Research & Development                2    Male          2
# 2   37  Research & Development                4    Male          1
# 3   33  Research & Development                5  Female          1
# 4   27  Research & Development                7    Male          1
#
#   marital_status over_time  performance_rating  totalW_working_years  \
# 0         Single       Yes                   3                     8
# 1        Married        No                   4                    10
# 2         Single       Yes                   3                     7
# 3        Married       Yes                   3                     8
# 4        Married        No                   3                     6
#
#    training_times_last_year  ...  years_with_curr_manager  monthly_income  \
# 0                         0  ...                        5            5993
# 1                         3  ...                        7            5130
# 2                         3  ...                        0            2090
# 3                         3  ...                        0            2909
# 4                         3  ...                        2            3468
#
#    salary_2017  salary_2018  year_of_joining  last_role_change  percent_hike  \
# 0        71916     79826.76             2012              2014            11
# 1        61560     75718.80             2008              2011            23
# 2        25080     28842.00             2018              2018            15
# 3        34908     38747.88             2010              2011            11
# 4        41616     46609.92             2016              2016            12
#
#    Tenure  hr_dummy  sales_dummy
# 0       8         0            1
# 1      12         0            0
# 2       2         0            0
# 3      10         0            0
# 4       4         0            0
#
# [5 rows x 21 columns]

# %%
df["hr_dummy"].value_counts()
# Out:
# 0    1407
# 1      63
# Name: hr_dummy, dtype: int64

# %%
df = df.drop(["hr_dummy","sales_dummy"],axis = 1)
df.columns
# Out:
# Index(['age', 'department', 'employee_number', 'gender', 'job_level',
#        'marital_status', 'over_time', 'performance_rating',
#        'totalW_working_years', 'training_times_last_year',
#        'years_since_last_promotion', 'years_with_curr_manager',
#        'monthly_income', 'salary_2017', 'salary_2018', 'year_of_joining',
#        'last_role_change', 'percent_hike', 'Tenure'],
#       dtype='object')

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    age  employee_number  job_level  performance_rating  totalW_working_years  \
# 0   41                1          2                   3                     8
# 1   49                2          2                   4                    10
# 2   37                4          1                   3                     7
# 3   33                5          1                   3                     8
# 4   27                7          1                   3                     6
#
#    training_times_last_year  years_since_last_promotion  \
# 0                         0                           0
# 1                         3                           1
# 2                         3                           0
# 3                         3                           3
# 4                         3                           2
#
#    years_with_curr_manager  monthly_income  salary_2017  ...  \
# 0                        5            5993        71916  ...
# 1                        7            5130        61560  ...
# 2                        0            2090        25080  ...
# 3                        0            2909        34908  ...
# 4                        2            3468        41616  ...
#
#    department_Human Resources  department_Research & Development  \
# 0                           0                                  0
# 1                           0                                  1
# 2                           0                                  1
# 3                           0                                  1
# 4                           0                                  1
#
#    department_Sales  gender_Female  gender_Male  marital_status_Divorced  \
# 0                 1              1            0                        0
# 1                 0              0            1                        0
# 2                 0              0            1                        0
# 3                 0              1            0                        0
# 4                 0              0            1                        0
#
#    marital_status_Married  marital_status_Single  over_time_No  over_time_Yes
# 0                       0                      1             0              1
# 1                       1                      0             1              0
# 2                       0                      1             0              1
# 3                       1                      0             0              1
# 4                       1                      0             1              0
#
# [5 rows x 25 columns]

# %%
df.apply(pd.Series.value_counts)
# Out:
#            age  employee_number  job_level  performance_rating  \
# 0.00       NaN              NaN        NaN                 NaN
# 1.00       NaN              1.0      543.0                 NaN
# 2.00       NaN              1.0      534.0                 NaN
# 3.00       NaN              NaN      218.0              1244.0
# 4.00       NaN              1.0      106.0               226.0
# ...        ...              ...        ...                 ...
# 284388.72  NaN              NaN        NaN                 NaN
# 286058.52  NaN              NaN        NaN                 NaN
# 287134.32  NaN              NaN        NaN                 NaN
# 292404.72  NaN              NaN        NaN                 NaN
# 295323.36  NaN              NaN        NaN                 NaN
#
#            totalW_working_years  training_times_last_year  \
# 0.00                       11.0                      54.0
# 1.00                       81.0                      71.0
# 2.00                       31.0                     547.0
# 3.00                       42.0                     491.0
# 4.00                       63.0                     123.0
# ...                         ...                       ...
# 284388.72                   NaN                       NaN
# 286058.52                   NaN                       NaN
# 287134.32                   NaN                       NaN
# 292404.72                   NaN                       NaN
# 295323.36                   NaN                       NaN
#
#            years_since_last_promotion  years_with_curr_manager  \
# 0.00                            581.0                    263.0
# 1.00                            357.0                     76.0
# 2.00                            159.0                    344.0
# 3.00                             52.0                    142.0
# 4.00                             61.0                     98.0
# ...                               ...                      ...
# 284388.72                         NaN                      NaN
# 286058.52                         NaN                      NaN
# 287134.32                         NaN                      NaN
# 292404.72                         NaN                      NaN
# 295323.36                         NaN                      NaN
#
#            monthly_income  salary_2017  ...  department_Human Resources  \
# 0.00                  NaN          NaN  ...                      1407.0
# 1.00                  NaN          NaN  ...                        63.0
# 2.00                  NaN          NaN  ...                         NaN
# 3.00                  NaN          NaN  ...                         NaN
# 4.00                  NaN          NaN  ...                         NaN
# ...                   ...          ...  ...                         ...
# 284388.72             NaN          NaN  ...                         NaN
# 286058.52             NaN          NaN  ...                         NaN
# 287134.32             NaN          NaN  ...                         NaN
# 292404.72             NaN          NaN  ...                         NaN
# 295323.36             NaN          NaN  ...                         NaN
#
#            department_Research & Development  department_Sales  gender_Female  \
# 0.00                                   509.0            1024.0          882.0
# 1.00                                   961.0             446.0          588.0
# 2.00                                     NaN               NaN            NaN
# 3.00                                     NaN               NaN            NaN
# 4.00                                     NaN               NaN            NaN
# ...                                      ...               ...            ...
# 284388.72                                NaN               NaN            NaN
# 286058.52                                NaN               NaN            NaN
# 287134.32                                NaN               NaN            NaN
# 292404.72                                NaN               NaN            NaN
# 295323.36                                NaN               NaN            NaN
#
#            gender_Male  marital_status_Divorced  marital_status_Married  \
# 0.00             588.0                   1143.0                   797.0
# 1.00             882.0                    327.0                   673.0
# 2.00               NaN                      NaN                     NaN
# 3.00               NaN                      NaN                     NaN
# 4.00               NaN                      NaN                     NaN
# ...                ...                      ...                     ...
# 284388.72          NaN                      NaN                     NaN
# 286058.52          NaN                      NaN                     NaN
# 287134.32          NaN                      NaN                     NaN
# 292404.72          NaN                      NaN                     NaN
# 295323.36          NaN                      NaN                     NaN
#
#            marital_status_Single  over_time_No  over_time_Yes
# 0.00                      1000.0         416.0         1054.0
# 1.00                       470.0        1054.0          416.0
# 2.00                         NaN           NaN            NaN
# 3.00                         NaN           NaN            NaN
# 4.00                         NaN           NaN            NaN
# ...                          ...           ...            ...
# 284388.72                    NaN           NaN            NaN
# 286058.52                    NaN           NaN            NaN
# 287134.32                    NaN           NaN            NaN
# 292404.72                    NaN           NaN            NaN
# 295323.36                    NaN           NaN            NaN
#
# [5610 rows x 25 columns]

# %%
df = df.drop(["gender_Male","department_Research & Development","marital_status_Married","over_time_No"],axis = 1)
df.head()
# Out:
#    age  employee_number  job_level  performance_rating  totalW_working_years  \
# 0   41                1          2                   3                     8
# 1   49                2          2                   4                    10
# 2   37                4          1                   3                     7
# 3   33                5          1                   3                     8
# 4   27                7          1                   3                     6
#
#    training_times_last_year  years_since_last_promotion  \
# 0                         0                           0
# 1                         3                           1
# 2                         3                           0
# 3                         3                           3
# 4                         3                           2
#
#    years_with_curr_manager  monthly_income  salary_2017  ...  year_of_joining  \
# 0                        5            5993        71916  ...             2012
# 1                        7            5130        61560  ...             2008
# 2                        0            2090        25080  ...             2018
# 3                        0            2909        34908  ...             2010
# 4                        2            3468        41616  ...             2016
#
#    last_role_change  percent_hike  Tenure  department_Human Resources  \
# 0              2014            11       8                           0
# 1              2011            23      12                           0
# 2              2018            15       2                           0
# 3              2011            11      10                           0
# 4              2016            12       4                           0
#
#    department_Sales  gender_Female  marital_status_Divorced  \
# 0                 1              1                        0
# 1                 0              0                        0
# 2                 0              0                        0
# 3                 0              1                        0
# 4                 0              0                        0
#
#    marital_status_Single  over_time_Yes
# 0                      1              1
# 1                      0              0
# 2                      1              1
# 3                      0              1
# 4                      0              0
#
# [5 rows x 21 columns]

# %% [markdown]
# <h3> Normalization

# %%
df = pd.read_excel("resources/skewness.xlsx")

# %%
df.head()
# Out:
#    manager_sat  employee_sat  salary_2017  percent_salary_hike  age
# 0           81            80       119968             0.952381   41
# 1           88            84        99330             1.818182   49
# 2           83            93       102511             1.739130   37
# 3           86            83        56674             1.666667   33
# 4           79            80       122021             2.400000   27

# %%
df["salary_2017"]
# Out:
# 0      119968
# 1       99330
# 2      102511
# 3       56674
# 4      122021
#         ...
# 681     74999
# 682     74999
# 683     74999
# 684     74999
# 685     74000
# Name: salary_2017, Length: 686, dtype: int64

# %%
df["salary_2017"].describe()
# Out:
# count       686.000000
# mean     114289.116618
# std       60820.924620
# min       39600.000000
# 25%       77033.750000
# 50%       98000.000000
# 75%      125705.500000
# max      511500.000000
# Name: salary_2017, dtype: float64

# %%
#min-max normalization
df["salary_2017_norm"] = (df["salary_2017"]-df["salary_2017"].min())/(df["salary_2017"].max()-df["salary_2017"].min())

# %%
df.head()
# Out:
#    manager_sat  employee_sat  salary_2017  percent_salary_hike  age  \
# 0           81            80       119968             0.952381   41
# 1           88            84        99330             1.818182   49
# 2           83            93       102511             1.739130   37
# 3           86            83        56674             1.666667   33
# 4           79            80       122021             2.400000   27
#
#    salary_2017_norm
# 0          0.170307
# 1          0.126573
# 2          0.133314
# 3          0.036181
# 4          0.174658

# %%
df["salary_2017_norm"].min()
# Out:
# 0.0

# %%
df["salary_2017_norm"].max()
# Out:
# 1.0

# %%
df["salary_2017"].hist()

# %%
df["salary_2017_norm"].hist()

# %% [markdown]
# <h3> Log Transformation </h3><p>
#     로그 트랜스포메이션은 데이터가 Right Skewed 되었을 때 사용한다.

# %%
df = pd.read_excel("resources/incentive.xlsx")

# %%
df.head()
# Out:
#    employee_number  incentive
# 0                1      278.5
# 1                2      271.0
# 2                3      209.5
# 3                4      208.0
# 4                5      198.0

# %%
df.count(axis=0)
# Out:
# employee_number    60
# incentive          60
# dtype: int64

# %%
df["incentive"].hist()

# %%
#skew data 를 log transform 으로 정규화
import numpy as np
import matplotlib.pyplot as plt
import
