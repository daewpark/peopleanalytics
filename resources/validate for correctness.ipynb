# %%
import pandas as pd
df= pd.read_excel('C:\\LR DATA.xlsx')

# %%
df.shape
# Out:
# (1470, 17)

# %%
df.columns
# Out:
# Index(['age', 'department', 'employee_number', 'gender', 'job_level',
#        'marital_status', 'over_time', 'performance_rating',
#        'totalW_working_years', 'training_times_last_year',
#        'years_since_last_promotion', 'years_with_curr_manager',
#        'monthly_income', 'salary_2017', 'salary_2018', 'year_of_joining',
#        'last_role_change'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    age              department  employee_number  gender  job_level  \
# 0   41                   Sales                1  Female          2
# 1   49  Research & Development                2    Male          2
# 2   37  Research & Development                4    Male          1
# 3   33  Research & Development                5  Female          1
# 4   27  Research & Development                7    Male          1
# 5   32  Research & Development                8    Male          1
# 6   59  Research & Development               10  Female          1
# 7   30  Research & Development               11    Male          1
# 8   38  Research & Development               12    Male          3
# 9   36  Research & Development               13    Male          2
#
#   marital_status over_time  performance_rating  totalW_working_years  \
# 0         Single       Yes                   3                     8
# 1        Married        No                   4                    10
# ...

# %%
df.tail(20)
# Out:
#       age              department  employee_number  gender  job_level  \
# 1450   35         Human Resources             2040  Female          3
# 1451   38                   Sales             2041  Female          2
# 1452   50                   Sales             2044    Male          2
# 1453   36                   Sales             2045  Female          2
# 1454   45                   Sales             2046  Female          2
# 1455   40  Research & Development             2048    Male          1
# 1456   35  Research & Development             2049    Male          2
# 1457   40  Research & Development             2051  Female          1
# 1458   35  Research & Development             2052  Female          1
# 1459   29  Research & Development             2053    Male          2
# 1460   29  Research & Development             2054  Female          1
# 1461   50                   Sales             2055    Male          3
# ...
