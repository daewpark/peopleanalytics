# %%
import pandas as pd
df= pd.read_excel('C:\\parallel plot data.xlsx')

# %%
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt

import seaborn as sns
 
# Make the plot
parallel_coordinates(df, 'department', colormap=plt.get_cmap("Set2"))
plt.show()
