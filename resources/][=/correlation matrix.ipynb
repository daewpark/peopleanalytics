# %%
import pandas as pd
df= pd.read_excel('C:\\mean median mode.xlsx')

# %%
df.age.corr(df['salary_2018'])
# Out:
# 0.49749035505602124

# %%
df1=df[['age','salary_2018','totalW_working_years','percent_hike']]

# %%
df1.corr()
# Out:
#                            age  salary_2018  totalW_working_years  \
# age                   1.000000     0.497490              0.680381
# salary_2018           0.497490     1.000000              0.772106
# totalW_working_years  0.680381     0.772106              1.000000
# percent_hike          0.003634     0.017307             -0.020608
#
#                       percent_hike
# age                       0.003634
# salary_2018               0.017307
# totalW_working_years     -0.020608
# percent_hike              1.000000

# %%
df.corr()
# Out:
#                                  age  employee_number  job_level  \
# age                         1.000000        -0.010145   0.509604
# employee_number            -0.010145         1.000000  -0.018519
# job_level                   0.509604        -0.018519   1.000000
# performance_rating          0.001904        -0.020359  -0.021222
# totalW_working_years        0.680381        -0.014365   0.782208
# training_times_last_year   -0.019621         0.023603  -0.018191
# years_since_last_promotion  0.216513        -0.009019   0.353885
# years_with_curr_manager     0.202089        -0.009197   0.375281
# monthly_income              0.497855        -0.014829   0.950300
# salary_2017                 0.497855        -0.014829   0.950300
# salary_2018                 0.497490        -0.013341   0.948134
# year_of_joining            -0.311309         0.011240  -0.534739
# last_role_change           -0.212901         0.008416  -0.389447
# percent_hike                0.003634        -0.012944  -0.034730
#
#                             performance_rating  totalW_working_years  \
# age                                   0.001904              0.680381
# employee_number                      -0.020359             -0.014365
# job_level                            -0.021222              0.782208
# performance_rating                    1.000000              0.006744
# totalW_working_years                  0.006744              1.000000
# training_times_last_year             -0.015579             -0.035662
# years_since_last_promotion            0.017896              0.404858
# years_with_curr_manager               0.022827              0.459188
# monthly_income                       -0.017120              0.772893
# salary_2017                          -0.017120              0.772893
# salary_2018                           0.016890              0.772106
# year_of_joining                      -0.003435             -0.628133
# last_role_change                     -0.034986             -0.460365
# percent_hike                          0.773550             -0.020608
#
#                             training_times_last_year  \
# age                                        -0.019621
# employee_number                             0.023603
# job_level                                  -0.018191
# performance_rating                         -0.015579
# totalW_working_years                       -0.035662
# training_times_last_year                    1.000000
# years_since_last_promotion                 -0.002067
# years_with_curr_manager                    -0.004096
# monthly_income                             -0.021736
# salary_2017                                -0.021736
# salary_2018                                -0.021365
# year_of_joining                            -0.003569
# last_role_change                            0.005738
# percent_hike                               -0.005221
#
#                             years_since_last_promotion  \
# age                                           0.216513
# employee_number                              -0.009019
# job_level                                     0.353885
# performance_rating                            0.017896
# totalW_working_years                          0.404858
# training_times_last_year                     -0.002067
# years_since_last_promotion                    1.000000
# years_with_curr_manager                       0.510224
# monthly_income                                0.344978
# salary_2017                                   0.344978
# salary_2018                                   0.343297
# year_of_joining                              -0.618409
# last_role_change                             -0.548056
# percent_hike                                 -0.022154
#
#                             years_with_curr_manager  monthly_income  \
# age                                        0.202089        0.497855
# employee_number                           -0.009197       -0.014829
# job_level                                  0.375281        0.950300
# performance_rating                         0.022827       -0.017120
# totalW_working_years                       0.459188        0.772893
# training_times_last_year                  -0.004096       -0.021736
# years_since_last_promotion                 0.510224        0.344978
# years_with_curr_manager                    1.000000        0.344079
# monthly_income                             0.344079        1.000000
# salary_2017                                0.344079        1.000000
# salary_2018                                0.343484        0.998482
# year_of_joining                           -0.769212       -0.514285
# last_role_change                          -0.714365       -0.363818
# percent_hike                              -0.011985       -0.027269
#
#                             salary_2017  salary_2018  year_of_joining  \
# age                            0.497855     0.497490        -0.311309
# employee_number               -0.014829    -0.013341         0.011240
# job_level                      0.950300     0.948134        -0.534739
# performance_rating            -0.017120     0.016890        -0.003435
# totalW_working_years           0.772893     0.772106        -0.628133
# training_times_last_year      -0.021736    -0.021365        -0.003569
# years_since_last_promotion     0.344978     0.343297        -0.618409
# years_with_curr_manager        0.344079     0.343484        -0.769212
# monthly_income                 1.000000     0.998482        -0.514285
# salary_2017                    1.000000     0.998482        -0.514285
# salary_2018                    0.998482     1.000000        -0.512096
# year_of_joining               -0.514285    -0.512096         1.000000
# last_role_change              -0.363818    -0.364510         0.758754
# percent_hike                  -0.027269     0.017307         0.035991
#
#                             last_role_change  percent_hike
# age                                -0.212901      0.003634
# employee_number                     0.008416     -0.012944
# job_level                          -0.389447     -0.034730
# performance_rating                 -0.034986      0.773550
# totalW_working_years               -0.460365     -0.020608
# training_times_last_year            0.005738     -0.005221
# years_since_last_promotion         -0.548056     -0.022154
# years_with_curr_manager            -0.714365     -0.011985
# monthly_income                     -0.363818     -0.027269
# salary_2017                        -0.363818     -0.027269
# salary_2018                        -0.364510      0.017307
# year_of_joining                     0.758754      0.035991
# last_role_change                    1.000000      0.001520
# percent_hike                        0.001520      1.000000
